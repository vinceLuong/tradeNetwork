# %% [markdown]
# ## Create Node2Vec Embeddings.
# We used modified versions of the Node2Vec Functions by A.Grover. Files under `node2vec_src` are the node2vec source files.
#
# Reference: https://github.com/aditya-grover/node2vec

# %%
# !python node2vec_src/main.py --input data/oil_k3_edgelists/oil_k3_2000.txt --output embeddings/oil_k3_2000.emd
# !python node2vec_src/main.py
# Out:
# Starting node2vec on file: data/oil_k3_edgelists\oil_k3_1988.txt
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# Completed node2vec, output: ./embeddings\oil_k3_1988.emb
# Starting node2vec on file: data/oil_k3_edgelists\oil_k3_1989.txt
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# Completed node2vec, output: ./embeddings\oil_k3_1989.emb
# Starting node2vec on file: data/oil_k3_edgelists\oil_k3_1990.txt
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# Completed node2vec, output: ./embeddings\oil_k3_1990.emb
# Starting node2vec on file: data/oil_k3_edgelists\oil_k3_1991.txt
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# Completed node2vec, output: ./embeddings\oil_k3_1991.emb
# ...
